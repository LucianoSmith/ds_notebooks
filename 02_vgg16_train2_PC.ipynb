# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# From local helper files
from helper_evaluation import set_all_seeds, set_deterministic, compute_confusion_matrix
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helper_dataset import get_dataloaders_cifar10, UnNormalize

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
# Out:
# cuda:1

# %%
set_all_seeds(RANDOM_SEED)
#set_deterministic()

# %%
##########################
### CIFAR-10 DATASET
##########################

### Note: Network trains about 2-3x faster if you don't
# resize (keeping the orig. 32x32 res.)
# Test acc. I got via the 32x32 was lower though; ~77%

train_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((70, 70)),
    torchvision.transforms.RandomCrop((64, 64)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

test_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((70, 70)),        
    torchvision.transforms.CenterCrop((64, 64)),            
    torchvision.transforms.ToTensor(),                
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


train_loader, valid_loader, test_loader = get_dataloaders_cifar10(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1,
    train_transforms=train_transforms,
    test_transforms=test_transforms,
    num_workers=2)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Files already downloaded and verified
# Image batch dimensions: torch.Size([256, 3, 64, 64])
# Image label dimensions: torch.Size([256])
# Class labels of 10 examples: tensor([4, 7, 4, 6, 2, 6, 9, 7, 3, 0])

# %%
##########################
### MODEL
##########################


class VGG16(torch.nn.Module):

    def __init__(self, num_classes):
        super().__init__()
        
        self.block_1 = torch.nn.Sequential(
                torch.nn.Conv2d(in_channels=3,
                                out_channels=64,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.Conv2d(in_channels=64,
                                out_channels=64,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))
        )
        
        self.block_2 = torch.nn.Sequential(
                torch.nn.Conv2d(in_channels=64,
                                out_channels=128,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.Conv2d(in_channels=128,
                                out_channels=128,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))
        )
        
        self.block_3 = torch.nn.Sequential(        
                torch.nn.Conv2d(in_channels=128,
                                out_channels=256,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.Conv2d(in_channels=256,
                                out_channels=256,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),        
                torch.nn.Conv2d(in_channels=256,
                                out_channels=256,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))
        )
        
          
        self.block_4 = torch.nn.Sequential(   
                torch.nn.Conv2d(in_channels=256,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),        
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),        
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),            
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))
        )
        
        self.block_5 = torch.nn.Sequential(
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),            
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),            
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),    
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))             
        )
            
        height, width = 3, 3 ## you may want to change that depending on the input image size
        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(512*height*width, 4096),
            torch.nn.ReLU(True),
            torch.nn.Dropout(p=0.5),
            torch.nn.Linear(4096, 4096),
            torch.nn.ReLU(True),
            torch.nn.Dropout(p=0.5),
            torch.nn.Linear(4096, num_classes),
        )
            
        for m in self.modules():
            if isinstance(m, torch.torch.nn.Conv2d) or isinstance(m, torch.torch.nn.Linear):
                torch.nn.init.kaiming_uniform_(m.weight, mode='fan_in', nonlinearity='relu')
                if m.bias is not None:
                    m.bias.detach().zero_()
                    
        self.avgpool = torch.nn.AdaptiveAvgPool2d((height, width))
        
        
    def forward(self, x):

        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.block_4(x)
        x = self.block_5(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), -1) # flatten
        
        logits = self.classifier(x)
        #probas = F.softmax(logits, dim=1)

        return logits

# %%
print(DEVICE)

#DEVICE = 'cpu'

DEVICE = torch.device('cuda:0')

print(DEVICE)
# Out:
# cuda:1
# cuda:0

# %%
model = VGG16(num_classes=10)

model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), momentum=0.9, lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=DEVICE,
    scheduler=scheduler,
    scheduler_on='valid_acc',
    logging_interval=100)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=200)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([60, 100])
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0175 | Loss: 3.4767
# Epoch: 001/050 | Batch 0100/0175 | Loss: 2.0947
# Epoch: 001/050 | Train: 33.49% | Validation: 33.62%
# Time elapsed: 2.42 min
# Epoch: 002/050 | Batch 0000/0175 | Loss: 1.7888
# Epoch: 002/050 | Batch 0100/0175 | Loss: 1.5998
# Epoch: 002/050 | Train: 48.01% | Validation: 48.66%
# Time elapsed: 4.83 min
# Epoch: 003/050 | Batch 0000/0175 | Loss: 1.4652
# Epoch: 003/050 | Batch 0100/0175 | Loss: 1.4753
# Epoch: 003/050 | Train: 53.23% | Validation: 53.66%
# Time elapsed: 6.98 min
# Epoch: 004/050 | Batch 0000/0175 | Loss: 1.1658
# Epoch: 004/050 | Batch 0100/0175 | Loss: 1.1828
# Epoch: 004/050 | Train: 61.84% | Validation: 62.02%
# Time elapsed: 9.14 min
# Epoch: 005/050 | Batch 0000/0175 | Loss: 1.1169
# Epoch: 005/050 | Batch 0100/0175 | Loss: 1.1086
# Epoch: 005/050 | Train: 65.48% | Validation: 65.76%
# Time elapsed: 11.37 min
# Epoch: 006/050 | Batch 0000/0175 | Loss: 0.8416
# Epoch: 006/050 | Batch 0100/0175 | Loss: 0.9130
# Epoch: 006/050 | Train: 72.25% | Validation: 71.80%
# Time elapsed: 13.52 min
# Epoch: 007/050 | Batch 0000/0175 | Loss: 0.7629
# Epoch: 007/050 | Batch 0100/0175 | Loss: 0.8560
# Epoch: 007/050 | Train: 74.25% | Validation: 72.66%
# Time elapsed: 15.98 min
# Epoch: 008/050 | Batch 0000/0175 | Loss: 0.7714
# Epoch: 008/050 | Batch 0100/0175 | Loss: 0.6426
# Epoch: 008/050 | Train: 77.95% | Validation: 74.98%
# Time elapsed: 18.49 min
# Epoch: 009/050 | Batch 0000/0175 | Loss: 0.5843
# Epoch: 009/050 | Batch 0100/0175 | Loss: 0.5905
# Epoch: 009/050 | Train: 81.86% | Validation: 78.42%
# Time elapsed: 20.53 min
# Epoch: 010/050 | Batch 0000/0175 | Loss: 0.6396
# Epoch: 010/050 | Batch 0100/0175 | Loss: 0.5549
# Epoch: 010/050 | Train: 82.58% | Validation: 78.86%
# Time elapsed: 22.60 min
# Epoch: 011/050 | Batch 0000/0175 | Loss: 0.5479
# Epoch: 011/050 | Batch 0100/0175 | Loss: 0.5453
# Epoch: 011/050 | Train: 84.96% | Validation: 78.80%
# Time elapsed: 24.67 min
# Epoch: 012/050 | Batch 0000/0175 | Loss: 0.4070
# Epoch: 012/050 | Batch 0100/0175 | Loss: 0.3811
# Epoch: 012/050 | Train: 87.38% | Validation: 81.60%
# Time elapsed: 26.73 min
# Epoch: 013/050 | Batch 0000/0175 | Loss: 0.3337
# Epoch: 013/050 | Batch 0100/0175 | Loss: 0.3607
# Epoch: 013/050 | Train: 88.29% | Validation: 81.38%
# Time elapsed: 29.61 min
# Epoch: 014/050 | Batch 0000/0175 | Loss: 0.3112
# Epoch: 014/050 | Batch 0100/0175 | Loss: 0.5014
# Epoch: 014/050 | Train: 90.21% | Validation: 81.82%
# Time elapsed: 31.85 min
# Epoch: 015/050 | Batch 0000/0175 | Loss: 0.3417
# Epoch: 015/050 | Batch 0100/0175 | Loss: 0.3091
# Epoch: 015/050 | Train: 92.71% | Validation: 83.22%
# Time elapsed: 33.93 min
# Epoch: 016/050 | Batch 0000/0175 | Loss: 0.1779
# Epoch: 016/050 | Batch 0100/0175 | Loss: 0.2642
# Epoch: 016/050 | Train: 93.21% | Validation: 82.80%
# Time elapsed: 36.01 min
# Epoch: 017/050 | Batch 0000/0175 | Loss: 0.2206
# Epoch: 017/050 | Batch 0100/0175 | Loss: 0.1500
# Epoch: 017/050 | Train: 93.67% | Validation: 83.04%
# Time elapsed: 38.18 min
# Epoch: 018/050 | Batch 0000/0175 | Loss: 0.1800
# Epoch: 018/050 | Batch 0100/0175 | Loss: 0.1822
# Epoch: 018/050 | Train: 94.21% | Validation: 83.16%
# Time elapsed: 40.78 min
# Epoch: 019/050 | Batch 0000/0175 | Loss: 0.2050
# Epoch: 019/050 | Batch 0100/0175 | Loss: 0.2017
# Epoch: 019/050 | Train: 95.71% | Validation: 83.74%
# Time elapsed: 43.58 min
# Epoch: 020/050 | Batch 0000/0175 | Loss: 0.1367
# Epoch: 020/050 | Batch 0100/0175 | Loss: 0.1997
# Epoch: 020/050 | Train: 95.36% | Validation: 83.22%
# Time elapsed: 46.35 min
# Epoch: 021/050 | Batch 0000/0175 | Loss: 0.1514
# Epoch: 021/050 | Batch 0100/0175 | Loss: 0.1967
# Epoch: 021/050 | Train: 95.35% | Validation: 82.66%
# Time elapsed: 48.90 min
# Epoch: 022/050 | Batch 0000/0175 | Loss: 0.1214
# Epoch: 022/050 | Batch 0100/0175 | Loss: 0.1348
# Epoch: 022/050 | Train: 96.38% | Validation: 83.52%
# Time elapsed: 51.62 min
# Epoch: 023/050 | Batch 0000/0175 | Loss: 0.1259
# Epoch: 023/050 | Batch 0100/0175 | Loss: 0.1778
# Epoch: 023/050 | Train: 97.22% | Validation: 84.70%
# Time elapsed: 54.35 min
# Epoch: 024/050 | Batch 0000/0175 | Loss: 0.0617
# Epoch: 024/050 | Batch 0100/0175 | Loss: 0.1702
# Epoch: 024/050 | Train: 97.99% | Validation: 85.06%
# Time elapsed: 57.46 min
# Epoch: 025/050 | Batch 0000/0175 | Loss: 0.0892
# Epoch: 025/050 | Batch 0100/0175 | Loss: 0.0964
# Epoch: 025/050 | Train: 97.85% | Validation: 84.16%
# Time elapsed: 60.03 min
# Epoch: 026/050 | Batch 0000/0175 | Loss: 0.1092
# Epoch: 026/050 | Batch 0100/0175 | Loss: 0.0919
# Epoch: 026/050 | Train: 97.92% | Validation: 84.20%
# Time elapsed: 62.67 min
# Epoch: 027/050 | Batch 0000/0175 | Loss: 0.0676
# Epoch: 027/050 | Batch 0100/0175 | Loss: 0.0926
# Epoch: 027/050 | Train: 98.29% | Validation: 85.00%
# Time elapsed: 65.28 min
# Epoch: 028/050 | Batch 0000/0175 | Loss: 0.0598
# Epoch: 028/050 | Batch 0100/0175 | Loss: 0.0658
# Epoch: 028/050 | Train: 98.15% | Validation: 84.28%
# Time elapsed: 67.87 min
# Epoch: 029/050 | Batch 0000/0175 | Loss: 0.0824
# Epoch: 029/050 | Batch 0100/0175 | Loss: 0.0267
# Epoch: 029/050 | Train: 97.90% | Validation: 84.62%
# Time elapsed: 70.41 min
# Epoch: 030/050 | Batch 0000/0175 | Loss: 0.0375
# Epoch: 030/050 | Batch 0100/0175 | Loss: 0.0527
# Epoch: 030/050 | Train: 98.34% | Validation: 84.40%
# Time elapsed: 72.96 min
# Epoch: 031/050 | Batch 0000/0175 | Loss: 0.0704
# Epoch: 031/050 | Batch 0100/0175 | Loss: 0.0231
# Epoch: 031/050 | Train: 97.90% | Validation: 83.92%
# Time elapsed: 75.49 min
# Epoch: 032/050 | Batch 0000/0175 | Loss: 0.0227
# Epoch: 032/050 | Batch 0100/0175 | Loss: 0.0880
# Epoch: 032/050 | Train: 99.09% | Validation: 85.04%
# Time elapsed: 77.76 min
# Epoch: 033/050 | Batch 0000/0175 | Loss: 0.0265
# Epoch: 033/050 | Batch 0100/0175 | Loss: 0.0614
# Epoch: 033/050 | Train: 98.38% | Validation: 83.98%
# Time elapsed: 79.82 min
# Epoch: 034/050 | Batch 0000/0175 | Loss: 0.0611
# Epoch: 034/050 | Batch 0100/0175 | Loss: 0.0478
# Epoch: 034/050 | Train: 98.92% | Validation: 85.10%
# Time elapsed: 81.88 min
# Epoch: 035/050 | Batch 0000/0175 | Loss: 0.0864
# Epoch: 035/050 | Batch 0100/0175 | Loss: 0.0468
# Epoch: 035/050 | Train: 99.23% | Validation: 85.76%
# Time elapsed: 83.96 min
# Epoch: 036/050 | Batch 0000/0175 | Loss: 0.0414
# Epoch: 036/050 | Batch 0100/0175 | Loss: 0.0270
# Epoch: 036/050 | Train: 99.03% | Validation: 84.98%
# Time elapsed: 86.04 min
# Epoch: 037/050 | Batch 0000/0175 | Loss: 0.0498
# Epoch: 037/050 | Batch 0100/0175 | Loss: 0.0723
# Epoch: 037/050 | Train: 99.12% | Validation: 84.84%
# Time elapsed: 88.77 min
# Epoch: 038/050 | Batch 0000/0175 | Loss: 0.0284
# Epoch: 038/050 | Batch 0100/0175 | Loss: 0.0480
# Epoch: 038/050 | Train: 99.21% | Validation: 84.98%
# Time elapsed: 91.45 min
# Epoch: 039/050 | Batch 0000/0175 | Loss: 0.0075
# Epoch: 039/050 | Batch 0100/0175 | Loss: 0.0518
# Epoch: 039/050 | Train: 99.42% | Validation: 85.08%
# Time elapsed: 94.10 min
# Epoch: 040/050 | Batch 0000/0175 | Loss: 0.0143
# Epoch: 040/050 | Batch 0100/0175 | Loss: 0.1013
# Epoch: 040/050 | Train: 98.98% | Validation: 84.22%
# Time elapsed: 96.64 min
# Epoch: 041/050 | Batch 0000/0175 | Loss: 0.0112
# Epoch: 041/050 | Batch 0100/0175 | Loss: 0.0323
# Epoch: 041/050 | Train: 99.03% | Validation: 85.02%
# Time elapsed: 99.21 min
# Epoch: 042/050 | Batch 0000/0175 | Loss: 0.0231
# Epoch: 042/050 | Batch 0100/0175 | Loss: 0.0409
# Epoch: 042/050 | Train: 99.42% | Validation: 85.12%
# Time elapsed: 101.73 min
# Epoch: 043/050 | Batch 0000/0175 | Loss: 0.0226
# Epoch: 043/050 | Batch 0100/0175 | Loss: 0.0814
# Epoch: 043/050 | Train: 99.33% | Validation: 84.48%
# Time elapsed: 104.22 min
# Epoch: 044/050 | Batch 0000/0175 | Loss: 0.0351
# Epoch: 044/050 | Batch 0100/0175 | Loss: 0.0475
# Epoch: 044/050 | Train: 99.52% | Validation: 85.72%
# Time elapsed: 106.74 min
# Epoch: 045/050 | Batch 0000/0175 | Loss: 0.0112
# Epoch: 045/050 | Batch 0100/0175 | Loss: 0.0247
# Epoch: 045/050 | Train: 98.98% | Validation: 84.24%
# Time elapsed: 109.28 min
# Epoch: 046/050 | Batch 0000/0175 | Loss: 0.0264
# Epoch: 046/050 | Batch 0100/0175 | Loss: 0.0059
# Epoch: 046/050 | Train: 99.47% | Validation: 84.84%
# Time elapsed: 111.81 min
# Epoch 00046: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 047/050 | Batch 0000/0175 | Loss: 0.0170
# Epoch: 047/050 | Batch 0100/0175 | Loss: 0.0053
# Epoch: 047/050 | Train: 99.89% | Validation: 86.36%
# Time elapsed: 114.48 min
# Epoch: 048/050 | Batch 0000/0175 | Loss: 0.0020
# Epoch: 048/050 | Batch 0100/0175 | Loss: 0.0013
# Epoch: 048/050 | Train: 99.92% | Validation: 86.68%
# Time elapsed: 116.94 min
# Epoch: 049/050 | Batch 0000/0175 | Loss: 0.0028
# Epoch: 049/050 | Batch 0100/0175 | Loss: 0.0055
# Epoch: 049/050 | Train: 99.96% | Validation: 86.80%
# Time elapsed: 119.39 min
# Epoch: 050/050 | Batch 0000/0175 | Loss: 0.0033
# Epoch: 050/050 | Batch 0100/0175 | Loss: 0.0029
# Epoch: 050/050 | Train: 99.96% | Validation: 86.90%
# Time elapsed: 121.83 min
# Total Training Time: 121.83 min
# Test accuracy 85.97%

# %%
# tras dos horas
torch.save(model.state_dict(), './vgg16_version1.pth')

# %%
model = torch.load('./vgg16_version1.pth')

# %%
#model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
class_dict = {0: 'airplane',
              1: 'automobile',
              2: 'bird',
              3: 'cat',
              4: 'deer',
              5: 'dog',
              6: 'frog',
              7: 'horse',
              8: 'ship',
              9: 'truck'}

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 14
#       2 unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
#       3 class_dict = {0: 'airplane',
#       4               1: 'automobile',
#       5               2: 'bird',
#    (...)
#      11               8: 'ship',
#      12               9: 'truck'}
# ---> 14 show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)
#
# File c:\Users\Luciano M. Smith\Documents\IA\ds_notebooks\helper_plotting.py:82, in show_examples(model, data_loader, unnormalizer, class_dict)
#      80     features = features
#      81     targets = targets
# ---> 82     logits = model(features)
#      83     predictions = torch.argmax(logits, dim=1)
#      84 break
#
# TypeError: 'collections.OrderedDict' object is not callable

# %%
mat = compute_confusion_matrix(model=model, data_loader=test_loader, device=torch.device('cpu'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mat = compute_confusion_matrix(model=model, data_loader=test_loader, device=torch.device('cpu'))
#       2 plot_confusion_matrix(mat, class_names=class_dict.values())
#       3 plt.show()
#
# NameError: name 'compute_confusion_matrix' is not defined
