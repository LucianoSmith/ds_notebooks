# %% [markdown]
# # Ejercicio Data Augmentation
#
# En este ejercicio se utilizará el dataset de manos, en el cual hay imágenes de 64x64 pixeles a color divididas en 6 clases, cada una representando un número distinto (0, 1, 2, 3, 4 o 5) indicado con los dedos de la mano.
#
# El conjunto de entrenamiento fue modificado de forma tal que el mismo sobreentrene una red neuronal convolucional si no se aplica ningún tipo de data augmentation. Dentro de la carpeta `train/` se encuentran 6 carpetas, cada una con 30 imágenes. El conjunto de validación no fue modificado. El mismo se encuentra en la carpeta `valid/` con 20 imágenes en cada clase.
#
# El objetivo de este ejercicio es, entonces, realizar entrenamientos de una misma arquitectura de red convolucional, utilizando data augmentation para obtener la mejor performance posible.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import os

import torch
import torchvision
import torchsummary
import torchmetrics
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ### Visualización de los datos
#
# Con la siguiente celda de código podemos visualizar una imagen de cada clase, tomada al azar, del conjunto de entrenamiento. Siempre es importante tener nocion de como lucen las imágenes de nuestro set de datos, tanto de entrenamiento como validación. Esto nos ayudará a saber que tipos de transformaciones serán más útiles cuando realicemos data augmentation.

# %%
train_folder = './ds_dataset/train/'
  

fig, axs = plt.subplots(1, 2, figsize=(10, 10))

for id, class_folder in enumerate(sorted(os.listdir(train_folder))):

    image_name = random.choice(os.listdir(os.path.join(train_folder, class_folder)))
    image = mpimg.imread(os.path.join(train_folder, class_folder, image_name))

    axs[id].imshow(image)
    axs[id].set_title(class_folder)

# %% [markdown]
# ### Definimos nuestra función de entrenamiento

# %%
def train(model, optimizer, criterion, metric, data, epochs, tb_writer=None):

    train_loader = data["train"]
    valid_loader = data["valid"]

    train_writer = tb_writer["train"]
    valid_writer = tb_writer["valid"]

    if tb_writer:
        train_writer.add_graph(model, torch.zeros((1, 3, data["image_width"], data["image_height"])))
        valid_writer.add_graph(model, torch.zeros((1, 3, data["image_width"], data["image_height"])))

    if torch.cuda.is_available():
        model.to("cuda")
        metric.to("cuda")

    train_loss = []
    train_acc = []
    valid_loss = []
    valid_acc = []

    for epoch in range(epochs):

        # Pongo el modelo en modo entrenamiento
        model.train()

        epoch_train_loss = 0.0
        epoch_train_accuracy = 0.0

        for train_data, train_target in train_loader:

            if torch.cuda.is_available():
                print("CUDA")
                train_data.to("cuda")
                train_target.to("cuda")

            optimizer.zero_grad()
            output = model(train_data.float())
            
            #train_target = train_target[:, None] ## MODIF
            #loss = criterion(output, train_target.float())   ## MODIF
            loss = criterion(output, train_target)   ## MODIF

            epoch_train_loss += loss.item()
            loss.backward()
            optimizer.step()
            
            accuracy = metric(output, train_target)
            epoch_train_accuracy += accuracy.item()

        epoch_train_loss = epoch_train_loss / len(train_loader)
        epoch_train_accuracy = epoch_train_accuracy / len(train_loader)
        train_loss.append(epoch_train_loss)
        train_acc.append(epoch_train_accuracy)

        # Pongo el modelo en modo testeo
        model.eval()

        epoch_valid_loss = 0.0
        epoch_valid_accuracy = 0.0

        for valid_data, valid_target in valid_loader:
            if torch.cuda.is_available():
                valid_data.to("cuda")
                valid_target.to("cuda")

            output = model(valid_data.float())

            #valid_target = valid_target[:, None] ## MODIF

            epoch_valid_loss += criterion(output, valid_target).item() 
            epoch_valid_accuracy += metric(output, valid_target).item()

        epoch_valid_loss = epoch_valid_loss / len(valid_loader)
        epoch_valid_accuracy = epoch_valid_accuracy / len(valid_loader)
        valid_loss.append(epoch_valid_loss)
        valid_acc.append(epoch_valid_accuracy)

        print("Epoch: {}/{} - Train loss {:.6f} - Train Accuracy {:.6f} - Valid Loss {:.6f} - Valid Accuracy {:.6f}".format(
        epoch+1, epochs, epoch_train_loss, epoch_train_accuracy, epoch_valid_loss, epoch_valid_accuracy))

        if tb_writer:
            train_writer.add_scalar("loss", epoch_train_loss, epoch)
            valid_writer.add_scalar("loss", epoch_valid_loss, epoch)
            train_writer.add_scalar("accuracy", epoch_train_accuracy, epoch)
            valid_writer.add_scalar("accuracy", epoch_valid_accuracy, epoch)
            train_writer.flush()
            valid_writer.flush()

    history = {}
    history["train_loss"] = train_loss
    history["train_acc"] = train_acc
    history["valid_loss"] = valid_loss
    history["valid_acc"] = valid_acc

    return history

# %% [markdown]
# ### Definimos nuestra arquitectura de red neuronal
#
# En la siguiente celda se define una clase para una red neuronal convolucional con 4 capas convolucionales, cada una seguida de un max pooling. Luego del último bloque convolucional-pooling se realiza un flatten y se agregan 2 capas densas para la clasificación.
#
# Para que esta celda funcione se debe completar el valor de `in_features` de la primera capa densa, el cual se puede calcular sabiendo el tamaño de las imágenes de entrada a la red, y cómo afecta cada capa convolucional y de pooling a las dimensión del tensor de entrada de dicha capa densa.

# %%
CANTIDAD_CLASES = 2
ANCHO_IMAGENES = 144
ALTO_IMAGENES = 144

# %%
class ConvModel(torch.nn.Module):
    def __init__(self, output_units):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding='same') # 144 x 144
        self.pool1 = torch.nn.MaxPool2d(kernel_size=2, stride=2) # 72 x 72
        self.conv2 = torch.nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding='same')
        self.pool2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) # 36 x 36
        self.conv3 = torch.nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding='same')
        self.pool3 = torch.nn.MaxPool2d(kernel_size=2, stride=2) # 18 x 18
        self.conv4 = torch.nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding='same')
        self.pool4 = torch.nn.MaxPool2d(kernel_size=2, stride=2) # 9 x 9
        self.fc1 = torch.nn.Linear(in_features=128*9*9, out_features=512)       ## MODIF
        #output_units = 1 ## MODIF 
        self.fc2 = torch.nn.Linear(in_features=512, out_features=output_units)  

    def forward(self, x):
        x = self.pool1(torch.relu(self.conv1(x)))
        x = self.pool2(torch.relu(self.conv2(x)))
        x = self.pool3(torch.relu(self.conv3(x)))
        x = self.pool4(torch.relu(self.conv4(x)))
        x = torch.flatten(x, 1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        #return x
        return torch.sigmoid(x) ## MODIF 

conv_model = ConvModel(CANTIDAD_CLASES)

# Si hay una GPU disponible muevo el modelo allí para aprovechar ese recurso
if torch.cuda.is_available():
    conv_model.to("cuda")

torchsummary.summary(conv_model, (3, ANCHO_IMAGENES, ALTO_IMAGENES))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 144, 144]             448
#          MaxPool2d-2           [-1, 16, 72, 72]               0
#             Conv2d-3           [-1, 32, 72, 72]           4,640
#          MaxPool2d-4           [-1, 32, 36, 36]               0
#             Conv2d-5           [-1, 64, 36, 36]          18,496
#          MaxPool2d-6           [-1, 64, 18, 18]               0
#             Conv2d-7          [-1, 128, 18, 18]          73,856
#          MaxPool2d-8            [-1, 128, 9, 9]               0
#             Linear-9                  [-1, 512]       5,308,928
#            Linear-10                    [-1, 2]           1,026
# ================================================================
# Total params: 5,407,394
# Trainable params: 5,407,394
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.24
# Forward/backward pass size (MB): 5.94
# Params size (MB): 20.63
# Estimated Total Size (MB): 26.80
# ----------------------------------------------------------------

# %% [markdown]
# ### 1) Entrenar sin aplicar Data Augmentation
#
# En primer lugar se define una composición de transformaciones que no realice ninguna modificación sobre las imágenes más que pasarlas a tensores, como lo pide torchvision. Luego se definen los `DataLoaders` para el entrenamiento.

# %%
data_transforms = torchvision.transforms.Compose([
                    torchvision.transforms.Resize(size=(ANCHO_IMAGENES, ALTO_IMAGENES)),
                    torchvision.transforms.ToTensor()
                  ])

train_set = torchvision.datasets.ImageFolder(root='./ds_dataset/train', transform=data_transforms)
valid_set = torchvision.datasets.ImageFolder(root='./ds_dataset/valid', transform=data_transforms)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size=32, shuffle=True)

# %% [markdown]
# Realizar el entrenamiento de la red durante 30 épocas y observar el sobreentrenamiento que se genera en el modelo.

# %%
noaug_conv_model = ConvModel(CANTIDAD_CLASES)
noaug_optimizer = torch.optim.Adam(noaug_conv_model.parameters(), lr=0.001)


noaug_loss = torch.nn.CrossEntropyLoss()    
#noaug_loss = torch.nn.BCEWithLogitsLoss()    ## MODIF
noaug_metric = torchmetrics.Accuracy(task='multiclass', num_classes=CANTIDAD_CLASES)
noaug_data = {"train": train_loader, "valid": valid_loader, "image_width": ANCHO_IMAGENES, "image_height": ALTO_IMAGENES}

noaug_writer = {"train": SummaryWriter(log_dir="data_aug/noaug_train"),
                "valid": SummaryWriter(log_dir="data_aug/noaug_valid")}

history = train(noaug_conv_model,
                noaug_optimizer,
                noaug_loss,
                noaug_metric,
                noaug_data,
                50,
                noaug_writer)

fig, axs = plt.subplots(2, 1, figsize=(10, 10))

axs[0].plot(history["train_loss"])
axs[0].plot(history["valid_loss"])
axs[0].title.set_text('Error de Entrenamiento vs Validación')
axs[0].legend(['Train', 'Valid'])

axs[1].plot(history["train_acc"])
axs[1].plot(history["valid_acc"])
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación')
axs[1].legend(['Train', 'Valid'])
# Out:
# Epoch: 1/50 - Train loss 0.697443 - Train Accuracy 0.487069 - Valid Loss 0.690962 - Valid Accuracy 0.545625
# Epoch: 2/50 - Train loss 0.690020 - Train Accuracy 0.569325 - Valid Loss 0.690399 - Valid Accuracy 0.541250
# Epoch: 3/50 - Train loss 0.685922 - Train Accuracy 0.573635 - Valid Loss 0.689504 - Valid Accuracy 0.541250
# Epoch: 4/50 - Train loss 0.683824 - Train Accuracy 0.574713 - Valid Loss 0.685917 - Valid Accuracy 0.558750
# Epoch: 5/50 - Train loss 0.686315 - Train Accuracy 0.568247 - Valid Loss 0.692476 - Valid Accuracy 0.545625
# Epoch: 6/50 - Train loss 0.689386 - Train Accuracy 0.566092 - Valid Loss 0.694577 - Valid Accuracy 0.545625
# Epoch: 7/50 - Train loss 0.683192 - Train Accuracy 0.570402 - Valid Loss 0.690360 - Valid Accuracy 0.541250
# Epoch: 8/50 - Train loss 0.682396 - Train Accuracy 0.568247 - Valid Loss 0.690297 - Valid Accuracy 0.536875
# Epoch: 9/50 - Train loss 0.681983 - Train Accuracy 0.569325 - Valid Loss 0.687437 - Valid Accuracy 0.545625
# Epoch: 10/50 - Train loss 0.682013 - Train Accuracy 0.568247 - Valid Loss 0.686491 - Valid Accuracy 0.550000
# Epoch: 11/50 - Train loss 0.680138 - Train Accuracy 0.571480 - Valid Loss 0.689157 - Valid Accuracy 0.536875
# Epoch: 12/50 - Train loss 0.678991 - Train Accuracy 0.572557 - Valid Loss 0.685338 - Valid Accuracy 0.545625
# Epoch: 13/50 - Train loss 0.675680 - Train Accuracy 0.573635 - Valid Loss 0.682117 - Valid Accuracy 0.558750
# Epoch: 14/50 - Train loss 0.673337 - Train Accuracy 0.568247 - Valid Loss 0.689742 - Valid Accuracy 0.541250
# Epoch: 15/50 - Train loss 0.662187 - Train Accuracy 0.570402 - Valid Loss 0.682324 - Valid Accuracy 0.554375
# Epoch: 16/50 - Train loss 0.650642 - Train Accuracy 0.619253 - Valid Loss 0.678300 - Valid Accuracy 0.585625
# Epoch: 17/50 - Train loss 0.614332 - Train Accuracy 0.720546 - Valid Loss 0.683087 - Valid Accuracy 0.561250
# Epoch: 18/50 - Train loss 0.581452 - Train Accuracy 0.804957 - Valid Loss 0.676453 - Valid Accuracy 0.565625
# Epoch: 19/50 - Train loss 0.564601 - Train Accuracy 0.711207 - Valid Loss 0.669198 - Valid Accuracy 0.574375
# Epoch: 20/50 - Train loss 0.517194 - Train Accuracy 0.806034 - Valid Loss 0.662314 - Valid Accuracy 0.608125
# Epoch: 21/50 - Train loss 0.488854 - Train Accuracy 0.830101 - Valid Loss 0.621816 - Valid Accuracy 0.632500
# Epoch: 22/50 - Train loss 0.471320 - Train Accuracy 0.850934 - Valid Loss 0.586687 - Valid Accuracy 0.699375
# Epoch: 23/50 - Train loss 0.430086 - Train Accuracy 0.880029 - Valid Loss 0.554066 - Valid Accuracy 0.739375
# Epoch: 24/50 - Train loss 0.378467 - Train Accuracy 0.946839 - Valid Loss 0.477441 - Valid Accuracy 0.830625
# Epoch: 25/50 - Train loss 0.355268 - Train Accuracy 0.967672 - Valid Loss 0.453705 - Valid Accuracy 0.850625
# Epoch: 26/50 - Train loss 0.346416 - Train Accuracy 0.989583 - Valid Loss 0.446202 - Valid Accuracy 0.870625
# Epoch: 27/50 - Train loss 0.333397 - Train Accuracy 0.989583 - Valid Loss 0.458373 - Valid Accuracy 0.841875
# Epoch: 28/50 - Train loss 0.331481 - Train Accuracy 0.988506 - Valid Loss 0.469702 - Valid Accuracy 0.853125
# Epoch: 29/50 - Train loss 0.330708 - Train Accuracy 0.978089 - Valid Loss 0.488424 - Valid Accuracy 0.801875
# Epoch: 30/50 - Train loss 0.329045 - Train Accuracy 0.988506 - Valid Loss 0.478425 - Valid Accuracy 0.826250
# Epoch: 31/50 - Train loss 0.322240 - Train Accuracy 1.000000 - Valid Loss 0.528316 - Valid Accuracy 0.773125
# Epoch: 32/50 - Train loss 0.326030 - Train Accuracy 0.989583 - Valid Loss 0.468559 - Valid Accuracy 0.837500
# Epoch: 33/50 - Train loss 0.329098 - Train Accuracy 0.988506 - Valid Loss 0.465022 - Valid Accuracy 0.830625
# Epoch: 34/50 - Train loss 0.324255 - Train Accuracy 0.989583 - Valid Loss 0.489231 - Valid Accuracy 0.826250
# Epoch: 35/50 - Train loss 0.322898 - Train Accuracy 1.000000 - Valid Loss 0.458905 - Valid Accuracy 0.848750
# Epoch: 36/50 - Train loss 0.316233 - Train Accuracy 1.000000 - Valid Loss 0.471710 - Valid Accuracy 0.826250
# Epoch: 37/50 - Train loss 0.319363 - Train Accuracy 1.000000 - Valid Loss 0.491778 - Valid Accuracy 0.808750
# Epoch: 38/50 - Train loss 0.320603 - Train Accuracy 1.000000 - Valid Loss 0.465973 - Valid Accuracy 0.833125
# Epoch: 39/50 - Train loss 0.322250 - Train Accuracy 0.988506 - Valid Loss 0.472071 - Valid Accuracy 0.821875
# Epoch: 40/50 - Train loss 0.325254 - Train Accuracy 0.988506 - Valid Loss 0.496964 - Valid Accuracy 0.793125
# Epoch: 41/50 - Train loss 0.316686 - Train Accuracy 1.000000 - Valid Loss 0.472537 - Valid Accuracy 0.830625
# Epoch: 42/50 - Train loss 0.320746 - Train Accuracy 0.989583 - Valid Loss 0.503825 - Valid Accuracy 0.795000
# Epoch: 43/50 - Train loss 0.317883 - Train Accuracy 1.000000 - Valid Loss 0.516521 - Valid Accuracy 0.801875
# Epoch: 44/50 - Train loss 0.313956 - Train Accuracy 1.000000 - Valid Loss 0.463046 - Valid Accuracy 0.846250
# Epoch: 45/50 - Train loss 0.314054 - Train Accuracy 1.000000 - Valid Loss 0.457070 - Valid Accuracy 0.841875
# Epoch: 46/50 - Train loss 0.313973 - Train Accuracy 1.000000 - Valid Loss 0.448108 - Valid Accuracy 0.866250
# Epoch: 47/50 - Train loss 0.313898 - Train Accuracy 1.000000 - Valid Loss 0.450533 - Valid Accuracy 0.861875
# Epoch: 48/50 - Train loss 0.314477 - Train Accuracy 1.000000 - Valid Loss 0.442630 - Valid Accuracy 0.886250
# Epoch: 49/50 - Train loss 0.313716 - Train Accuracy 1.000000 - Valid Loss 0.449183 - Valid Accuracy 0.877500
# Epoch: 50/50 - Train loss 0.313337 - Train Accuracy 1.000000 - Valid Loss 0.448640 - Valid Accuracy 0.846250

# %%
noaug_conv_model.eval()
# Out:
# ConvModel(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=10368, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
from PIL import Image

def preprocesar_imagen(imagen_path):
    transformacion = torchvision.transforms.Compose([
        torchvision.transforms.Resize(size=(ANCHO_IMAGENES, ALTO_IMAGENES)),
        torchvision.transforms.ToTensor(),
        #torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    imagen = Image.open(imagen_path)
    imagen = transformacion(imagen)
    imagen = imagen.unsqueeze(0)  # Agregar dimensión batch
    return imagen

# %%
def predecir_imagen(imagen_path, modelo):
    
    imagen = preprocesar_imagen(imagen_path)

    with torch.no_grad():
        salida = modelo(imagen)
    output = salida.numpy()
    
    c = (max(output[0][0], output[0][1])/(output[0][0] + output[0][1]))

    _, indice_prediccion = torch.max(salida, 1)
    
    return indice_prediccion.item(), c

# %%
# ds_dataset/test/017-36.png    MACHO    1
# ds_dataset/test/017-37.png    MACHO    1
# ds_dataset/test/017-42.png    MACHO    1
# ds_dataset/test/023-73.png    HEMBRA    0
# ds_dataset/test/023-75.png    HEMBRA    0
# ds_dataset/test/024-4.png    HEMBRA    0



indice_prediccion = predecir_imagen('ds_dataset/test/024-4.png', noaug_conv_model)

print(f'La imagen pertenece a la clase: {indice_prediccion}')
# Out:
# La imagen pertenece a la clase: 0

# %%
clases = ['h', 'm']

folder = './ds_dataset/test/DS_DATASET/'

r = 9
  
fig, axs = plt.subplots(r, r, figsize=(20, 20))

axs = axs.flatten()
ok = 0
m = 0
h= 0
mp = 0
hp =0 
for i in axs:

        image_h = random.choice(os.listdir(os.path.join(folder, 'h/')))
        image_m = random.choice(os.listdir(os.path.join(folder, 'm/')))

        
        image_name = random.choice([image_h, image_m])
        
        sex = 'm'
        m = m +1
        file = os.path.join(folder, 'm/', image_m)
        if (image_name==image_h): 
            sex = 'h'
            h=h+1
            m=m-1
            file = os.path.join(folder, 'h/', image_h)
    
        indice_prediccion, c = predecir_imagen(file, noaug_conv_model)

        c = c*100
        #title = sex + " / PRED: " + clases[indice_prediccion]
        #title = sex + (' (ok)' if sex==clases[indice_prediccion] else ' (err)') + f' {c:.2f} %' 
        title = sex + f' {c:.2f} %' 


        #print("Epoch: {}/{} - Train loss {:.6f} - Train Accuracy {:.6f} - Valid Loss {:.6f} - Valid Accuracy {:.6f}".format(
        #epoch+1, epochs, epoch_train_loss, epoch_train_accuracy, epoch_valid_loss, epoch_valid_accuracy))

        fg_color = 'red'
        if sex==clases[indice_prediccion]: 
            fg_color = 'green'
            ok += 1
        test_image = mpimg.imread(file)
        
        if clases[indice_prediccion]=='m': 
            mp += 1
        else:
            hp += 1

        i.imshow(test_image)
        i.set_title(title, color= fg_color)
        i.axis("off")



print(f'Imágenes procesadas: {r**2}')
print(f'Cantidad de machos reales/encontrados: {m} / {mp}')
print(f'Cantidad de hembras reales/encontrados: {h} / {hp}')
print(f'Porcentaje correctos: {(ok/(r**2))*100:.2f} %')
# Out:
# Imágenes procesadas: 81
# Cantidad de machos reales/encontrados: 47 / 53
# Cantidad de hembras reales/encontrados: 34 / 28
# Porcentaje correctos: 92.59 %

# %% [markdown]
# ---
# ### 2) Entrenar aplicando Data Augmentation
#
# A continuación se define una composición de transformaciones para aplicar data augmentation sobre el conjunto de entrenamiento.
#
# Ejecutar la celda para entrenar durante, al menos, 100 épocas y analizar los resultados.

# %%
aug_data_transforms = torchvision.transforms.Compose([
                        torchvision.transforms.RandomHorizontalFlip(0.5),
                        torchvision.transforms.RandomResizedCrop(size=(64, 64), scale=(0.2, 0.7)),
                        torchvision.transforms.RandomRotation(degrees=90),
                        torchvision.transforms.RandomPerspective(0.8),
                        torchvision.transforms.RandomGrayscale(0.5),
                        torchvision.transforms.ToTensor(),
                      ])

aug_train_set = torchvision.datasets.ImageFolder(root='./dataset_manos_modificado/train', transform=aug_data_transforms)

aug_train_loader = torch.utils.data.DataLoader(aug_train_set, batch_size=32, shuffle=True)

# %%
aug_conv_model = ConvModel(CANTIDAD_CLASES)
aug_optimizer = torch.optim.Adam(aug_conv_model.parameters(), lr=0.001)
aug_loss = torch.nn.CrossEntropyLoss()
aug_metric = torchmetrics.Accuracy(task='multiclass', num_classes=CANTIDAD_CLASES)
aug_data = {"train": aug_train_loader, "valid": valid_loader, "image_width": ANCHO_IMAGENES, "image_height": ALTO_IMAGENES}

aug_writer = {"train": SummaryWriter(log_dir="data_aug/aug_train"),
              "valid": SummaryWriter(log_dir="data_aug/aug_valid")}

history = train(aug_conv_model,
                aug_optimizer,
                aug_loss,
                aug_metric,
                aug_data,
                100,
                aug_writer)

fig, axs = plt.subplots(2, 1, figsize=(10, 10))

axs[0].plot(history["train_loss"])
axs[0].plot(history["valid_loss"])
axs[0].title.set_text('Error de Entrenamiento vs Validación')
axs[0].legend(['Train', 'Valid'])

axs[1].plot(history["train_acc"])
axs[1].plot(history["valid_acc"])
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación')
axs[1].legend(['Train', 'Valid'])
# Out:
# Epoch: 1/100 - Train loss 1.805398 - Train Accuracy 0.153646 - Valid Loss 1.791462 - Valid Accuracy 0.166667
# Epoch: 2/100 - Train loss 1.792734 - Train Accuracy 0.164062 - Valid Loss 1.791725 - Valid Accuracy 0.166667
# Epoch: 3/100 - Train loss 1.792335 - Train Accuracy 0.145833 - Valid Loss 1.791698 - Valid Accuracy 0.166667
# Epoch: 4/100 - Train loss 1.791959 - Train Accuracy 0.169271 - Valid Loss 1.791764 - Valid Accuracy 0.164062
# Epoch: 5/100 - Train loss 1.792172 - Train Accuracy 0.158854 - Valid Loss 1.791761 - Valid Accuracy 0.166667
# Epoch: 6/100 - Train loss 1.792308 - Train Accuracy 0.164062 - Valid Loss 1.791750 - Valid Accuracy 0.166667
# Epoch: 7/100 - Train loss 1.791934 - Train Accuracy 0.169271 - Valid Loss 1.791920 - Valid Accuracy 0.166667
# Epoch: 8/100 - Train loss 1.791892 - Train Accuracy 0.166667 - Valid Loss 1.791625 - Valid Accuracy 0.174479
# Epoch: 9/100 - Train loss 1.792148 - Train Accuracy 0.158854 - Valid Loss 1.791784 - Valid Accuracy 0.161458
# Epoch: 10/100 - Train loss 1.791965 - Train Accuracy 0.143229 - Valid Loss 1.792034 - Valid Accuracy 0.161458
# Epoch: 11/100 - Train loss 1.792296 - Train Accuracy 0.184896 - Valid Loss 1.791807 - Valid Accuracy 0.166667
# Epoch: 12/100 - Train loss 1.792018 - Train Accuracy 0.166667 - Valid Loss 1.791842 - Valid Accuracy 0.166667
# Epoch: 13/100 - Train loss 1.791938 - Train Accuracy 0.179688 - Valid Loss 1.791862 - Valid Accuracy 0.158854
# Epoch: 14/100 - Train loss 1.792322 - Train Accuracy 0.096354 - Valid Loss 1.791783 - Valid Accuracy 0.166667
# Epoch: 15/100 - Train loss 1.791957 - Train Accuracy 0.169271 - Valid Loss 1.791780 - Valid Accuracy 0.164062
# Epoch: 16/100 - Train loss 1.792289 - Train Accuracy 0.135417 - Valid Loss 1.791769 - Valid Accuracy 0.161458
# Epoch: 17/100 - Train loss 1.792002 - Train Accuracy 0.161458 - Valid Loss 1.791813 - Valid Accuracy 0.169271
# Epoch: 18/100 - Train loss 1.791800 - Train Accuracy 0.164062 - Valid Loss 1.791790 - Valid Accuracy 0.164062
# Epoch: 19/100 - Train loss 1.792070 - Train Accuracy 0.164062 - Valid Loss 1.791764 - Valid Accuracy 0.166667
# Epoch: 20/100 - Train loss 1.791840 - Train Accuracy 0.169271 - Valid Loss 1.791772 - Valid Accuracy 0.166667
# Epoch: 21/100 - Train loss 1.791809 - Train Accuracy 0.166667 - Valid Loss 1.791769 - Valid Accuracy 0.166667
# Epoch: 22/100 - Train loss 1.791836 - Train Accuracy 0.166667 - Valid Loss 1.791771 - Valid Accuracy 0.166667
# Epoch: 23/100 - Train loss 1.791888 - Train Accuracy 0.164062 - Valid Loss 1.791747 - Valid Accuracy 0.161458
# Epoch: 24/100 - Train loss 1.791971 - Train Accuracy 0.171875 - Valid Loss 1.791721 - Valid Accuracy 0.166667
# Epoch: 25/100 - Train loss 1.791665 - Train Accuracy 0.174479 - Valid Loss 1.791782 - Valid Accuracy 0.158854
# Epoch: 26/100 - Train loss 1.791919 - Train Accuracy 0.166667 - Valid Loss 1.791497 - Valid Accuracy 0.169271
# Epoch: 27/100 - Train loss 1.791685 - Train Accuracy 0.166667 - Valid Loss 1.791810 - Valid Accuracy 0.161458
# Epoch: 28/100 - Train loss 1.792185 - Train Accuracy 0.156250 - Valid Loss 1.791567 - Valid Accuracy 0.158854
# Epoch: 29/100 - Train loss 1.791795 - Train Accuracy 0.171875 - Valid Loss 1.791243 - Valid Accuracy 0.171875
# Epoch: 30/100 - Train loss 1.792151 - Train Accuracy 0.153646 - Valid Loss 1.790941 - Valid Accuracy 0.169271
# Epoch: 31/100 - Train loss 1.792659 - Train Accuracy 0.164062 - Valid Loss 1.791708 - Valid Accuracy 0.161458
# Epoch: 32/100 - Train loss 1.791776 - Train Accuracy 0.169271 - Valid Loss 1.791823 - Valid Accuracy 0.161458
# Epoch: 33/100 - Train loss 1.791809 - Train Accuracy 0.169271 - Valid Loss 1.791656 - Valid Accuracy 0.166667
# Epoch: 34/100 - Train loss 1.791945 - Train Accuracy 0.161458 - Valid Loss 1.791780 - Valid Accuracy 0.161458
# Epoch: 35/100 - Train loss 1.791667 - Train Accuracy 0.203125 - Valid Loss 1.791581 - Valid Accuracy 0.174479
# Epoch: 36/100 - Train loss 1.792090 - Train Accuracy 0.166667 - Valid Loss 1.791677 - Valid Accuracy 0.164062
# Epoch: 37/100 - Train loss 1.791902 - Train Accuracy 0.119792 - Valid Loss 1.791721 - Valid Accuracy 0.161458
# Epoch: 38/100 - Train loss 1.791933 - Train Accuracy 0.171875 - Valid Loss 1.791624 - Valid Accuracy 0.229167
# Epoch: 39/100 - Train loss 1.791977 - Train Accuracy 0.174479 - Valid Loss 1.791705 - Valid Accuracy 0.231771
# Epoch: 40/100 - Train loss 1.791977 - Train Accuracy 0.169271 - Valid Loss 1.791633 - Valid Accuracy 0.255208
# Epoch: 41/100 - Train loss 1.792000 - Train Accuracy 0.169271 - Valid Loss 1.791623 - Valid Accuracy 0.210938
# Epoch: 42/100 - Train loss 1.791864 - Train Accuracy 0.143229 - Valid Loss 1.791823 - Valid Accuracy 0.166667
# Epoch: 43/100 - Train loss 1.791831 - Train Accuracy 0.166667 - Valid Loss 1.791658 - Valid Accuracy 0.174479
# Epoch: 44/100 - Train loss 1.791807 - Train Accuracy 0.169271 - Valid Loss 1.791706 - Valid Accuracy 0.177083
# Epoch: 45/100 - Train loss 1.791915 - Train Accuracy 0.169271 - Valid Loss 1.791743 - Valid Accuracy 0.164062
# Epoch: 46/100 - Train loss 1.791919 - Train Accuracy 0.164062 - Valid Loss 1.791778 - Valid Accuracy 0.166667
# Epoch: 47/100 - Train loss 1.791840 - Train Accuracy 0.169271 - Valid Loss 1.791728 - Valid Accuracy 0.166667
# Epoch: 48/100 - Train loss 1.791891 - Train Accuracy 0.169271 - Valid Loss 1.791738 - Valid Accuracy 0.166667
# Epoch: 49/100 - Train loss 1.791810 - Train Accuracy 0.153646 - Valid Loss 1.791743 - Valid Accuracy 0.255208
# Epoch: 50/100 - Train loss 1.792052 - Train Accuracy 0.153646 - Valid Loss 1.791695 - Valid Accuracy 0.166667
# Epoch: 51/100 - Train loss 1.791946 - Train Accuracy 0.161458 - Valid Loss 1.791650 - Valid Accuracy 0.166667
# Epoch: 52/100 - Train loss 1.791540 - Train Accuracy 0.223958 - Valid Loss 1.791530 - Valid Accuracy 0.179688
# Epoch: 53/100 - Train loss 1.791301 - Train Accuracy 0.184896 - Valid Loss 1.791207 - Valid Accuracy 0.177083
# Epoch: 54/100 - Train loss 1.790846 - Train Accuracy 0.190104 - Valid Loss 1.791735 - Valid Accuracy 0.171875
# Epoch: 55/100 - Train loss 1.793212 - Train Accuracy 0.184896 - Valid Loss 1.790717 - Valid Accuracy 0.164062
# Epoch: 56/100 - Train loss 1.791759 - Train Accuracy 0.140625 - Valid Loss 1.791115 - Valid Accuracy 0.200521
# Epoch: 57/100 - Train loss 1.790979 - Train Accuracy 0.190104 - Valid Loss 1.791071 - Valid Accuracy 0.169271
# Epoch: 58/100 - Train loss 1.791723 - Train Accuracy 0.166667 - Valid Loss 1.790230 - Valid Accuracy 0.174479
# Epoch: 59/100 - Train loss 1.791991 - Train Accuracy 0.158854 - Valid Loss 1.791407 - Valid Accuracy 0.239583
# Epoch: 60/100 - Train loss 1.792407 - Train Accuracy 0.132812 - Valid Loss 1.791801 - Valid Accuracy 0.169271
# Epoch: 61/100 - Train loss 1.792429 - Train Accuracy 0.161458 - Valid Loss 1.791711 - Valid Accuracy 0.166667
# Epoch: 62/100 - Train loss 1.792290 - Train Accuracy 0.143229 - Valid Loss 1.791858 - Valid Accuracy 0.195312
# Epoch: 63/100 - Train loss 1.792221 - Train Accuracy 0.161458 - Valid Loss 1.791839 - Valid Accuracy 0.161458
# Epoch: 64/100 - Train loss 1.792412 - Train Accuracy 0.122396 - Valid Loss 1.792048 - Valid Accuracy 0.161458
# Epoch: 65/100 - Train loss 1.792706 - Train Accuracy 0.140625 - Valid Loss 1.791903 - Valid Accuracy 0.161458
# Epoch: 66/100 - Train loss 1.792007 - Train Accuracy 0.166667 - Valid Loss 1.791827 - Valid Accuracy 0.164062
# Epoch: 67/100 - Train loss 1.791948 - Train Accuracy 0.161458 - Valid Loss 1.791683 - Valid Accuracy 0.174479
# Epoch: 68/100 - Train loss 1.791851 - Train Accuracy 0.166667 - Valid Loss 1.791809 - Valid Accuracy 0.166667
# Epoch: 69/100 - Train loss 1.791906 - Train Accuracy 0.164062 - Valid Loss 1.791745 - Valid Accuracy 0.166667
# Epoch: 70/100 - Train loss 1.791929 - Train Accuracy 0.164062 - Valid Loss 1.791734 - Valid Accuracy 0.166667
# Epoch: 71/100 - Train loss 1.792023 - Train Accuracy 0.156250 - Valid Loss 1.791813 - Valid Accuracy 0.164062
# Epoch: 72/100 - Train loss 1.791848 - Train Accuracy 0.166667 - Valid Loss 1.791745 - Valid Accuracy 0.166667
# Epoch: 73/100 - Train loss 1.791847 - Train Accuracy 0.166667 - Valid Loss 1.791744 - Valid Accuracy 0.166667
# Epoch: 74/100 - Train loss 1.791831 - Train Accuracy 0.166667 - Valid Loss 1.791722 - Valid Accuracy 0.169271
# Epoch: 75/100 - Train loss 1.791842 - Train Accuracy 0.148438 - Valid Loss 1.791787 - Valid Accuracy 0.164062
# Epoch: 76/100 - Train loss 1.791777 - Train Accuracy 0.166667 - Valid Loss 1.791787 - Valid Accuracy 0.164062
# Epoch: 77/100 - Train loss 1.791904 - Train Accuracy 0.119792 - Valid Loss 1.791684 - Valid Accuracy 0.169271
# Epoch: 78/100 - Train loss 1.791999 - Train Accuracy 0.122396 - Valid Loss 1.791749 - Valid Accuracy 0.166667
# Epoch: 79/100 - Train loss 1.791813 - Train Accuracy 0.169271 - Valid Loss 1.791760 - Valid Accuracy 0.177083
# Epoch: 80/100 - Train loss 1.791848 - Train Accuracy 0.164062 - Valid Loss 1.791748 - Valid Accuracy 0.166667
# Epoch: 81/100 - Train loss 1.791837 - Train Accuracy 0.166667 - Valid Loss 1.791753 - Valid Accuracy 0.169271
# Epoch: 82/100 - Train loss 1.791848 - Train Accuracy 0.164062 - Valid Loss 1.791823 - Valid Accuracy 0.158854
# Epoch: 83/100 - Train loss 1.791961 - Train Accuracy 0.164062 - Valid Loss 1.791702 - Valid Accuracy 0.174479
# Epoch: 84/100 - Train loss 1.791771 - Train Accuracy 0.143229 - Valid Loss 1.791725 - Valid Accuracy 0.169271
# Epoch: 85/100 - Train loss 1.791838 - Train Accuracy 0.156250 - Valid Loss 1.791780 - Valid Accuracy 0.161458
# Epoch: 86/100 - Train loss 1.791840 - Train Accuracy 0.166667 - Valid Loss 1.791809 - Valid Accuracy 0.158854
# Epoch: 87/100 - Train loss 1.792007 - Train Accuracy 0.138021 - Valid Loss 1.791770 - Valid Accuracy 0.169271
# Epoch: 88/100 - Train loss 1.791783 - Train Accuracy 0.164062 - Valid Loss 1.791722 - Valid Accuracy 0.177083
# Epoch: 89/100 - Train loss 1.791815 - Train Accuracy 0.156250 - Valid Loss 1.791776 - Valid Accuracy 0.164062
# Epoch: 90/100 - Train loss 1.791883 - Train Accuracy 0.169271 - Valid Loss 1.791679 - Valid Accuracy 0.177083
# Epoch: 91/100 - Train loss 1.791807 - Train Accuracy 0.171875 - Valid Loss 1.791794 - Valid Accuracy 0.158854
# Epoch: 92/100 - Train loss 1.791967 - Train Accuracy 0.161458 - Valid Loss 1.791725 - Valid Accuracy 0.169271
# Epoch: 93/100 - Train loss 1.791940 - Train Accuracy 0.161458 - Valid Loss 1.791789 - Valid Accuracy 0.164062
# Epoch: 94/100 - Train loss 1.791836 - Train Accuracy 0.177083 - Valid Loss 1.791769 - Valid Accuracy 0.166667
# Epoch: 95/100 - Train loss 1.791886 - Train Accuracy 0.158854 - Valid Loss 1.791763 - Valid Accuracy 0.164062
# Epoch: 96/100 - Train loss 1.791809 - Train Accuracy 0.171875 - Valid Loss 1.791728 - Valid Accuracy 0.166667
# Epoch: 97/100 - Train loss 1.791839 - Train Accuracy 0.166667 - Valid Loss 1.791740 - Valid Accuracy 0.169271
# Epoch: 98/100 - Train loss 1.791796 - Train Accuracy 0.166667 - Valid Loss 1.791763 - Valid Accuracy 0.161458
# Epoch: 99/100 - Train loss 1.791872 - Train Accuracy 0.169271 - Valid Loss 1.791712 - Valid Accuracy 0.164062
# Epoch: 100/100 - Train loss 1.791854 - Train Accuracy 0.171875 - Valid Loss 1.791729 - Valid Accuracy 0.177083

# %% [markdown]
# ###**Algunas preguntas para analizar**
#
# 1) ¿Es el resultado del entrenamiento aceptable?
#
# 2) ¿Está el Data Augmentation mejorando o empeorando el resultado?
#
# 3) Basándose en las características de las imágenes del conjunto de validación, diría que el tipo de transformaciones utilizadas es acertado? (Se puede usar la celda del principio del Colab para visualizar imágenes del conjunto de validación)
#
# 4) Basándose en los resultados del entrenamiento, diría que los parámetros de las transformaciones aplicadas tienen valores agresivos? (Se puede utilizar la celda siguiente para visualizar un conjunto de imágenes y sus versiones transformadas)

# %%
# Ploteo las imagenes sin augmentacion

images_ids = np.random.randint(low=0, high=len(train_set), size=4)

fig, rows = plt.subplots(nrows=1, ncols=4, figsize=(18, 18))
for id, row in enumerate(rows):
    row.imshow(train_set[images_ids[id]][0].permute(1, 2, 0))
    row.axis('off')
plt.show()

# Ploteo las mismas imagenes con augmentacion

fig, rows = plt.subplots(nrows=1, ncols=4, figsize=(18, 18))
for id, row in enumerate(rows):
    row.imshow(aug_train_set[images_ids[id]][0].permute(1, 2, 0))
    row.axis('off')
plt.show()

# %% [markdown]
# ### 3) Mejorar/corregir el Data Augmentation
#
# En base a su criterio y a las reflexiones de las preguntas anteriores, defina una nueva composición de transformaciones que ayude a obtener buenos resultados sobre el entrenamiento. Intentar obtener métricas que superen el 90% de accuracy sin caer en sobreentrenamiento. Incrementar la cantidad de épocas de entrenamiento si es necesario.

# %%
new_aug_data_transforms = torchvision.transforms.Compose([
                            torchvision.transforms.Resize(size=(ANCHO_IMAGENES, ALTO_IMAGENES)),
                            torchvision.transforms.RandomHorizontalFlip(0.5),
                            torchvision.transforms.RandomResizedCrop(size=(ANCHO_IMAGENES, ALTO_IMAGENES), scale=(0.8, 1)),
                            torchvision.transforms.RandomRotation(degrees=10, fill=210),
                            torchvision.transforms.RandomPerspective(0.1, fill=210),


                            torchvision.transforms.ToTensor(),
                        ])

new_aug_train_set = torchvision.datasets.ImageFolder(root='./dataset_manos_modificado/train', transform=new_aug_data_transforms)

new_aug_train_loader = torch.utils.data.DataLoader(new_aug_train_set, batch_size=32, shuffle=True)

# %%
new_aug_conv_model = ConvModel(CANTIDAD_CLASES)
new_aug_optimizer = torch.optim.Adam(new_aug_conv_model.parameters(), lr=0.001)
new_aug_loss = torch.nn.CrossEntropyLoss()
new_aug_metric = torchmetrics.Accuracy(task='multiclass', num_classes=CANTIDAD_CLASES)
new_aug_data = {"train": new_aug_train_loader, "valid": valid_loader, "image_width": ANCHO_IMAGENES, "image_height": ALTO_IMAGENES}

new_aug_writer = {"train": SummaryWriter(log_dir="data_aug/new_aug_train"),
                  "valid": SummaryWriter(log_dir="data_aug/new_aug_valid")}

history = train(new_aug_conv_model,
                new_aug_optimizer,
                new_aug_loss,
                new_aug_metric,
                new_aug_data,
                100,
                new_aug_writer)

fig, axs = plt.subplots(2, 1, figsize=(10, 10))

axs[0].plot(history["train_loss"])
axs[0].plot(history["valid_loss"])
axs[0].title.set_text('Error de Entrenamiento vs Validación')
axs[0].legend(['Train', 'Valid'])

axs[1].plot(history["train_acc"])
axs[1].plot(history["valid_acc"])
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación')
axs[1].legend(['Train', 'Valid'])
# Out:
# Epoch: 1/100 - Train loss 1.805988 - Train Accuracy 0.122396 - Valid Loss 1.792906 - Valid Accuracy 0.143229
# Epoch: 2/100 - Train loss 1.792848 - Train Accuracy 0.153646 - Valid Loss 1.791687 - Valid Accuracy 0.166667
# Epoch: 3/100 - Train loss 1.792510 - Train Accuracy 0.171875 - Valid Loss 1.792076 - Valid Accuracy 0.161458
# Epoch: 4/100 - Train loss 1.793020 - Train Accuracy 0.166667 - Valid Loss 1.791966 - Valid Accuracy 0.164062
# Epoch: 5/100 - Train loss 1.792132 - Train Accuracy 0.161458 - Valid Loss 1.791474 - Valid Accuracy 0.166667
# Epoch: 6/100 - Train loss 1.791767 - Train Accuracy 0.164062 - Valid Loss 1.791154 - Valid Accuracy 0.166667
# Epoch: 7/100 - Train loss 1.791911 - Train Accuracy 0.148438 - Valid Loss 1.790504 - Valid Accuracy 0.236979
# Epoch: 8/100 - Train loss 1.790098 - Train Accuracy 0.229167 - Valid Loss 1.788626 - Valid Accuracy 0.205729
# Epoch: 9/100 - Train loss 1.789019 - Train Accuracy 0.239583 - Valid Loss 1.785694 - Valid Accuracy 0.289062
# Epoch: 10/100 - Train loss 1.785722 - Train Accuracy 0.322917 - Valid Loss 1.779777 - Valid Accuracy 0.161458
# Epoch: 11/100 - Train loss 1.773762 - Train Accuracy 0.276042 - Valid Loss 1.764116 - Valid Accuracy 0.403646
# Epoch: 12/100 - Train loss 1.754716 - Train Accuracy 0.304688 - Valid Loss 1.716903 - Valid Accuracy 0.424479
# Epoch: 13/100 - Train loss 1.694304 - Train Accuracy 0.372396 - Valid Loss 1.615147 - Valid Accuracy 0.375000
# Epoch: 14/100 - Train loss 1.613887 - Train Accuracy 0.315104 - Valid Loss 1.484577 - Valid Accuracy 0.500000
# Epoch: 15/100 - Train loss 1.554928 - Train Accuracy 0.348958 - Valid Loss 1.591305 - Valid Accuracy 0.309896
# Epoch: 16/100 - Train loss 1.536807 - Train Accuracy 0.356771 - Valid Loss 1.373233 - Valid Accuracy 0.466146
# Epoch: 17/100 - Train loss 1.499556 - Train Accuracy 0.437500 - Valid Loss 1.345144 - Valid Accuracy 0.486979
# Epoch: 18/100 - Train loss 1.433264 - Train Accuracy 0.432292 - Valid Loss 1.306292 - Valid Accuracy 0.484375
# Epoch: 19/100 - Train loss 1.330353 - Train Accuracy 0.463542 - Valid Loss 1.242812 - Valid Accuracy 0.580729
# Epoch: 20/100 - Train loss 1.284303 - Train Accuracy 0.505208 - Valid Loss 1.211645 - Valid Accuracy 0.526042
# Epoch: 21/100 - Train loss 1.250815 - Train Accuracy 0.526042 - Valid Loss 1.086578 - Valid Accuracy 0.658854
# Epoch: 22/100 - Train loss 1.265076 - Train Accuracy 0.468750 - Valid Loss 1.066092 - Valid Accuracy 0.528646
# Epoch: 23/100 - Train loss 1.120212 - Train Accuracy 0.505208 - Valid Loss 1.108205 - Valid Accuracy 0.505208
# Epoch: 24/100 - Train loss 1.073713 - Train Accuracy 0.622396 - Valid Loss 1.062876 - Valid Accuracy 0.585938
# Epoch: 25/100 - Train loss 1.003543 - Train Accuracy 0.611979 - Valid Loss 0.981532 - Valid Accuracy 0.559896
# Epoch: 26/100 - Train loss 0.910801 - Train Accuracy 0.653646 - Valid Loss 0.868780 - Valid Accuracy 0.664062
# Epoch: 27/100 - Train loss 0.922049 - Train Accuracy 0.643229 - Valid Loss 0.878359 - Valid Accuracy 0.648438
# Epoch: 28/100 - Train loss 0.864056 - Train Accuracy 0.695312 - Valid Loss 0.903579 - Valid Accuracy 0.645833
# Epoch: 29/100 - Train loss 0.823354 - Train Accuracy 0.700521 - Valid Loss 0.903095 - Valid Accuracy 0.692708
# Epoch: 30/100 - Train loss 0.767220 - Train Accuracy 0.716146 - Valid Loss 0.860860 - Valid Accuracy 0.611979
# Epoch: 31/100 - Train loss 0.699856 - Train Accuracy 0.752604 - Valid Loss 0.827812 - Valid Accuracy 0.648438
# Epoch: 32/100 - Train loss 0.738256 - Train Accuracy 0.723958 - Valid Loss 0.842603 - Valid Accuracy 0.752604
# Epoch: 33/100 - Train loss 0.770273 - Train Accuracy 0.783854 - Valid Loss 0.770413 - Valid Accuracy 0.664062
# Epoch: 34/100 - Train loss 0.656696 - Train Accuracy 0.765625 - Valid Loss 0.863647 - Valid Accuracy 0.669271
# Epoch: 35/100 - Train loss 0.719298 - Train Accuracy 0.760417 - Valid Loss 0.757764 - Valid Accuracy 0.643229
# Epoch: 36/100 - Train loss 0.676851 - Train Accuracy 0.736979 - Valid Loss 0.750776 - Valid Accuracy 0.729167
# Epoch: 37/100 - Train loss 0.559116 - Train Accuracy 0.804688 - Valid Loss 0.687889 - Valid Accuracy 0.736979
# Epoch: 38/100 - Train loss 0.576979 - Train Accuracy 0.783854 - Valid Loss 0.731061 - Valid Accuracy 0.682292
# Epoch: 39/100 - Train loss 0.562610 - Train Accuracy 0.765625 - Valid Loss 0.793804 - Valid Accuracy 0.705729
# Epoch: 40/100 - Train loss 0.497018 - Train Accuracy 0.786458 - Valid Loss 0.689498 - Valid Accuracy 0.687500
# Epoch: 41/100 - Train loss 0.507423 - Train Accuracy 0.804688 - Valid Loss 0.754431 - Valid Accuracy 0.695312
# Epoch: 42/100 - Train loss 0.472933 - Train Accuracy 0.833333 - Valid Loss 0.662061 - Valid Accuracy 0.773438
# Epoch: 43/100 - Train loss 0.411961 - Train Accuracy 0.817708 - Valid Loss 0.643419 - Valid Accuracy 0.776042
# Epoch: 44/100 - Train loss 0.388110 - Train Accuracy 0.854167 - Valid Loss 0.679676 - Valid Accuracy 0.768229
# Epoch: 45/100 - Train loss 0.289039 - Train Accuracy 0.898438 - Valid Loss 0.757986 - Valid Accuracy 0.768229
# Epoch: 46/100 - Train loss 0.493304 - Train Accuracy 0.817708 - Valid Loss 0.780037 - Valid Accuracy 0.716146
# Epoch: 47/100 - Train loss 0.552114 - Train Accuracy 0.773438 - Valid Loss 0.869309 - Valid Accuracy 0.700521
# Epoch: 48/100 - Train loss 0.467937 - Train Accuracy 0.804688 - Valid Loss 0.630492 - Valid Accuracy 0.776042
# Epoch: 49/100 - Train loss 0.679074 - Train Accuracy 0.739583 - Valid Loss 0.647855 - Valid Accuracy 0.789062
# Epoch: 50/100 - Train loss 0.532104 - Train Accuracy 0.791667 - Valid Loss 0.658204 - Valid Accuracy 0.752604
# Epoch: 51/100 - Train loss 0.429678 - Train Accuracy 0.828125 - Valid Loss 0.666847 - Valid Accuracy 0.794271
# Epoch: 52/100 - Train loss 0.338815 - Train Accuracy 0.880208 - Valid Loss 0.679950 - Valid Accuracy 0.773438
# Epoch: 53/100 - Train loss 0.337725 - Train Accuracy 0.895833 - Valid Loss 0.671740 - Valid Accuracy 0.773438
# Epoch: 54/100 - Train loss 0.445151 - Train Accuracy 0.843750 - Valid Loss 0.824738 - Valid Accuracy 0.739583
# Epoch: 55/100 - Train loss 0.391600 - Train Accuracy 0.809896 - Valid Loss 0.597237 - Valid Accuracy 0.794271
# Epoch: 56/100 - Train loss 0.298282 - Train Accuracy 0.919271 - Valid Loss 0.689183 - Valid Accuracy 0.789062
# Epoch: 57/100 - Train loss 0.322447 - Train Accuracy 0.846354 - Valid Loss 0.742684 - Valid Accuracy 0.773438
# Epoch: 58/100 - Train loss 0.415413 - Train Accuracy 0.830729 - Valid Loss 0.726215 - Valid Accuracy 0.742188
# Epoch: 59/100 - Train loss 0.436933 - Train Accuracy 0.838542 - Valid Loss 0.566750 - Valid Accuracy 0.786458
# Epoch: 60/100 - Train loss 0.405992 - Train Accuracy 0.846354 - Valid Loss 0.615831 - Valid Accuracy 0.794271
# Epoch: 61/100 - Train loss 0.283872 - Train Accuracy 0.888021 - Valid Loss 0.731256 - Valid Accuracy 0.721354
# Epoch: 62/100 - Train loss 0.311738 - Train Accuracy 0.911458 - Valid Loss 0.557456 - Valid Accuracy 0.791667
# Epoch: 63/100 - Train loss 0.274371 - Train Accuracy 0.903646 - Valid Loss 0.554252 - Valid Accuracy 0.846354
# Epoch: 64/100 - Train loss 0.247889 - Train Accuracy 0.908854 - Valid Loss 0.647524 - Valid Accuracy 0.776042
# Epoch: 65/100 - Train loss 0.316662 - Train Accuracy 0.885417 - Valid Loss 0.567296 - Valid Accuracy 0.825521
# Epoch: 66/100 - Train loss 0.252605 - Train Accuracy 0.934896 - Valid Loss 0.713213 - Valid Accuracy 0.773438
# Epoch: 67/100 - Train loss 0.332435 - Train Accuracy 0.885417 - Valid Loss 0.625308 - Valid Accuracy 0.841146
# Epoch: 68/100 - Train loss 0.206687 - Train Accuracy 0.919271 - Valid Loss 0.513687 - Valid Accuracy 0.825521
# Epoch: 69/100 - Train loss 0.253736 - Train Accuracy 0.914062 - Valid Loss 0.621964 - Valid Accuracy 0.812500
# Epoch: 70/100 - Train loss 0.368671 - Train Accuracy 0.833333 - Valid Loss 0.632945 - Valid Accuracy 0.812500
# Epoch: 71/100 - Train loss 0.329131 - Train Accuracy 0.888021 - Valid Loss 0.500921 - Valid Accuracy 0.872396
# Epoch: 72/100 - Train loss 0.330217 - Train Accuracy 0.872396 - Valid Loss 0.546411 - Valid Accuracy 0.791667
# Epoch: 73/100 - Train loss 0.311527 - Train Accuracy 0.882812 - Valid Loss 0.526516 - Valid Accuracy 0.833333
# Epoch: 74/100 - Train loss 0.225101 - Train Accuracy 0.921875 - Valid Loss 0.473555 - Valid Accuracy 0.835938
# Epoch: 75/100 - Train loss 0.267132 - Train Accuracy 0.916667 - Valid Loss 0.475921 - Valid Accuracy 0.867188
# Epoch: 76/100 - Train loss 0.210193 - Train Accuracy 0.911458 - Valid Loss 0.535515 - Valid Accuracy 0.851562
# Epoch: 77/100 - Train loss 0.191734 - Train Accuracy 0.932292 - Valid Loss 0.532996 - Valid Accuracy 0.820312
# Epoch: 78/100 - Train loss 0.189689 - Train Accuracy 0.940104 - Valid Loss 0.587674 - Valid Accuracy 0.830729
# Epoch: 79/100 - Train loss 0.142386 - Train Accuracy 0.929688 - Valid Loss 0.563429 - Valid Accuracy 0.843750
# Epoch: 80/100 - Train loss 0.193323 - Train Accuracy 0.919271 - Valid Loss 0.435325 - Valid Accuracy 0.856771
# Epoch: 81/100 - Train loss 0.131799 - Train Accuracy 0.953125 - Valid Loss 0.491696 - Valid Accuracy 0.880208
# Epoch: 82/100 - Train loss 0.182130 - Train Accuracy 0.953125 - Valid Loss 0.442848 - Valid Accuracy 0.875000
# Epoch: 83/100 - Train loss 0.161381 - Train Accuracy 0.927083 - Valid Loss 0.542460 - Valid Accuracy 0.859375
# Epoch: 84/100 - Train loss 0.177745 - Train Accuracy 0.914062 - Valid Loss 0.481630 - Valid Accuracy 0.843750
# Epoch: 85/100 - Train loss 0.098731 - Train Accuracy 0.968750 - Valid Loss 0.528947 - Valid Accuracy 0.825521
# Epoch: 86/100 - Train loss 0.226889 - Train Accuracy 0.921875 - Valid Loss 0.656529 - Valid Accuracy 0.861979
# Epoch: 87/100 - Train loss 0.215103 - Train Accuracy 0.945312 - Valid Loss 0.622844 - Valid Accuracy 0.835938
# Epoch: 88/100 - Train loss 0.119828 - Train Accuracy 0.968750 - Valid Loss 0.470778 - Valid Accuracy 0.872396
# Epoch: 89/100 - Train loss 0.149063 - Train Accuracy 0.929688 - Valid Loss 0.533102 - Valid Accuracy 0.851562
# Epoch: 90/100 - Train loss 0.092770 - Train Accuracy 0.973958 - Valid Loss 0.519021 - Valid Accuracy 0.864583
# Epoch: 91/100 - Train loss 0.172094 - Train Accuracy 0.945312 - Valid Loss 0.536615 - Valid Accuracy 0.846354
# Epoch: 92/100 - Train loss 0.138187 - Train Accuracy 0.934896 - Valid Loss 0.475355 - Valid Accuracy 0.841146
# Epoch: 93/100 - Train loss 0.212703 - Train Accuracy 0.924479 - Valid Loss 0.679420 - Valid Accuracy 0.843750
# Epoch: 94/100 - Train loss 0.226827 - Train Accuracy 0.921875 - Valid Loss 0.484249 - Valid Accuracy 0.885417
# Epoch: 95/100 - Train loss 0.187689 - Train Accuracy 0.919271 - Valid Loss 0.482815 - Valid Accuracy 0.861979
# Epoch: 96/100 - Train loss 0.231358 - Train Accuracy 0.885417 - Valid Loss 0.491749 - Valid Accuracy 0.882812
# Epoch: 97/100 - Train loss 0.179596 - Train Accuracy 0.934896 - Valid Loss 0.595277 - Valid Accuracy 0.848958
# Epoch: 98/100 - Train loss 0.186701 - Train Accuracy 0.921875 - Valid Loss 0.537212 - Valid Accuracy 0.825521
# Epoch: 99/100 - Train loss 0.138261 - Train Accuracy 0.945312 - Valid Loss 0.460211 - Valid Accuracy 0.833333
# Epoch: 100/100 - Train loss 0.158748 - Train Accuracy 0.921875 - Valid Loss 0.584339 - Valid Accuracy 0.859375

# %%
new_aug_conv_model.eval()
# Out:
# ConvModel(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=2048, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=6, bias=True)
# )

# %%
from PIL import Image

def preprocesar_imagen(imagen_path):
    transformacion = torchvision.transforms.Compose([
        torchvision.transforms.Resize(size=(ANCHO_IMAGENES, ALTO_IMAGENES)),
        torchvision.transforms.ToTensor(),
        #torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    imagen = Image.open(imagen_path)
    imagen = transformacion(imagen)
    imagen = imagen.unsqueeze(0)  # Agregar dimensión batch
    return imagen

# %%
def predecir_imagen(imagen_path, modelo):
    
    imagen = preprocesar_imagen(imagen_path)

    with torch.no_grad():
        salida = modelo(imagen)

    _, indice_prediccion = torch.max(salida, 1)
    
    return indice_prediccion.item()

# %%
indice_prediccion = predecir_imagen('dataset_manos_modificado/valid/5/image_3.png', new_aug_conv_model)

print(f'La imagen pertenece a la clase: {indice_prediccion}')
# Out:
# La imagen pertenece a la clase: 5

# %% [markdown]
# ### Conclusiones
#
# - Que tipo de transformaciones son mas efectivas en este dataset?

# %%
x = torch.randn(16)
print(x)
print(x.shape)
x = x[:, None]
print(x.shape)
print(x)
# Out:
# tensor([ 1.7416,  0.5812,  0.4029,  0.8553,  1.1671,  0.3844,  0.4643, -1.0761,
#          0.3607,  0.5498,  0.4558,  0.3614, -0.1621,  0.9590,  1.2521, -1.1164])
# torch.Size([16])
# torch.Size([16, 1])
# tensor([[ 1.7416],
#         [ 0.5812],
#         [ 0.4029],
#         [ 0.8553],
#         [ 1.1671],
#         [ 0.3844],
#         [ 0.4643],
#         [-1.0761],
#         [ 0.3607],
#         [ 0.5498],
#         [ 0.4558],
#         [ 0.3614],
#         [-0.1621],
#         [ 0.9590],
#         [ 1.2521],
#         [-1.1164]])
